# %%
# use numpy and pandas
import pickle
import numpy as np
import pandas as pd

# We need sklearn for preprocessing and for the TSNE Algorithm.
import sklearn
from sklearn.preprocessing import scale

# %%
X_test=[386,382,356,331,320,315,307,272,244,232,237,258,212,2,-267,-605,-850,-1001,-1109,-1090,-967,-746,-464,-152,118,318,427,473,485,447,397,339,312,314,326,335,332,324,310,312,309,309,303,297,295,295,293,286,279,283,301,308,285,252,215,194,169,111,-74,-388,-679,-892,-949,-972,-1001,-1006,-949,-847,-668,-432,-153,72,226,326,392,461,495,513,511,496,479,453,440,427,414,399,385,385,404,432,444,437,418,392,373,363,365,372,385,388,383,371,360,353,334,303,252,200,153,151,143,48,-206,-548,-859,-1067,-1069,-957,-780,-597,-460,-357,-276,-224,-210,-350,-930,-1413,-1716,-1360,-662,-96,243,323,241,29,-167,-228,-136,27,146,229,269,297,307,303,305,306,307,280,231,159,85,51,43,62,63,63,69,89,123,136,127,102,95,105,131,163,168,164,150,146,152,157,156,154,143,129]
X_test
# Out:
# [386,
#  382,
#  356,
#  331,
#  320,
#  315,
#  307,
#  272,
#  244,
#  232,
#  237,
#  258,
#  212,
#  2,
#  -267,
#  -605,
#  -850,
#  -1001,
#  -1109,
#  -1090,
#  -967,
#  -746,
#  -464,
#  -152,
#  118,
#  318,
#  427,
#  473,
#  485,
#  447,
#  397,
#  339,
#  312,
#  314,
#  326,
#  335,
#  332,
#  324,
#  310,
#  312,
#  309,
#  309,
#  303,
#  297,
#  295,
#  295,
#  293,
#  286,
#  279,
#  283,
#  301,
#  308,
#  285,
#  252,
#  215,
#  194,
#  169,
#  111,
#  -74,
#  -388,
#  -679,
#  -892,
#  -949,
#  -972,
#  -1001,
#  -1006,
#  -949,
#  -847,
#  -668,
#  -432,
#  -153,
#  72,
#  226,
#  326,
#  392,
#  461,
#  495,
#  513,
#  511,
#  496,
#  479,
#  453,
#  440,
#  427,
#  414,
#  399,
#  385,
#  385,
#  404,
#  432,
#  444,
#  437,
#  418,
#  392,
#  373,
#  363,
#  365,
#  372,
#  385,
#  388,
#  383,
#  371,
#  360,
#  353,
#  334,
#  303,
#  252,
#  200,
#  153,
#  151,
#  143,
#  48,
#  -206,
#  -548,
#  -859,
#  -1067,
#  -1069,
#  -957,
#  -780,
#  -597,
#  -460,
#  -357,
#  -276,
#  -224,
#  -210,
#  -350,
#  -930,
#  -1413,
#  -1716,
#  -1360,
#  -662,
#  -96,
#  243,
#  323,
#  241,
#  29,
#  -167,
#  -228,
#  -136,
#  27,
#  146,
#  229,
#  269,
#  297,
#  307,
#  303,
#  305,
#  306,
#  307,
#  280,
#  231,
#  159,
#  85,
#  51,
#  43,
#  62,
#  63,
#  63,
#  69,
#  89,
#  123,
#  136,
#  127,
#  102,
#  95,
#  105,
#  131,
#  163,
#  168,
#  164,
#  150,
#  146,
#  152,
#  157,
#  156,
#  154,
#  143,
#  129]

# %%
X_test=scale(X_test)
#X_test=[X_test]
X_test=list(X_test)
X_test=[X_test]
X_test=np.asarray(X_test)
X_test
# Out:
# array([[  7.58500358e-01,   7.50022833e-01,   6.94918920e-01,
#           6.41934389e-01,   6.18621195e-01,   6.08024289e-01,
#           5.91069239e-01,   5.16890895e-01,   4.57548219e-01,
#           4.32115644e-01,   4.42712550e-01,   4.87219557e-01,
#           3.89728019e-01,  -5.53420455e-02,  -6.25455604e-01,
#          -1.34180647e+00,  -1.86105488e+00,  -2.18108145e+00,
#          -2.40997462e+00,  -2.36970638e+00,  -2.10902249e+00,
#          -1.64063923e+00,  -1.04297371e+00,  -3.81726759e-01,
#           1.90506181e-01,   6.14382432e-01,   8.45394990e-01,
#           9.42886528e-01,   9.68319103e-01,   8.87782615e-01,
#           7.81813552e-01,   6.58889439e-01,   6.01666145e-01,
#           6.05904907e-01,   6.31337483e-01,   6.50411914e-01,
#           6.44053770e-01,   6.27098720e-01,   5.97427382e-01,
#           6.01666145e-01,   5.95308001e-01,   5.95308001e-01,
#           5.82591714e-01,   5.69875426e-01,   5.65636663e-01,
#           5.65636663e-01,   5.61397901e-01,   5.46562232e-01,
#           5.31726563e-01,   5.40204088e-01,   5.78352951e-01,
#           5.93188620e-01,   5.44442851e-01,   4.74503269e-01,
#           3.96086163e-01,   3.51579156e-01,   2.98594625e-01,
#           1.75670512e-01,  -2.16415021e-01,  -8.81900737e-01,
#          -1.49864068e+00,  -1.95006889e+00,  -2.07087362e+00,
#          -2.11961939e+00,  -2.18108145e+00,  -2.19167835e+00,
#          -2.07087362e+00,  -1.85469673e+00,  -1.47532749e+00,
#          -9.75153512e-01,  -3.83846141e-01,   9.30146427e-02,
#           4.19399357e-01,   6.31337483e-01,   7.71216646e-01,
#           9.17453953e-01,   9.89512915e-01,   1.02766178e+00,
#           1.02342302e+00,   9.91632297e-01,   9.55602815e-01,
#           9.00498902e-01,   8.72946946e-01,   8.45394990e-01,
#           8.17843033e-01,   7.86052314e-01,   7.56380977e-01,
#           7.56380977e-01,   7.96649221e-01,   8.55991896e-01,
#           8.81424471e-01,   8.66588802e-01,   8.26320558e-01,
#           7.71216646e-01,   7.30948402e-01,   7.09754589e-01,
#           7.13993352e-01,   7.28829020e-01,   7.56380977e-01,
#           7.62739121e-01,   7.52142214e-01,   7.26709639e-01,
#           7.03396445e-01,   6.88560777e-01,   6.48292533e-01,
#           5.82591714e-01,   4.74503269e-01,   3.64295444e-01,
#           2.64684525e-01,   2.60445762e-01,   2.43490712e-01,
#           4.21494925e-02,  -4.96173347e-01,  -1.22100174e+00,
#          -1.88012931e+00,  -2.32096061e+00,  -2.32519937e+00,
#          -2.08782867e+00,  -1.71269819e+00,  -1.32485142e+00,
#          -1.03449619e+00,  -8.16199918e-01,  -6.44530036e-01,
#          -5.34322210e-01,  -5.04650872e-01,  -8.01364249e-01,
#          -2.03060538e+00,  -3.05426653e+00,  -3.69643905e+00,
#          -2.94193932e+00,  -1.46261120e+00,  -2.63041409e-01,
#           4.55428838e-01,   6.24979339e-01,   4.51190075e-01,
#           1.88124853e-03,  -4.13517478e-01,  -5.42799735e-01,
#          -3.47816659e-01,  -2.35751398e-03,   2.49848856e-01,
#           4.25757500e-01,   5.10532751e-01,   5.69875426e-01,
#           5.91069239e-01,   5.82591714e-01,   5.86830476e-01,
#           5.88949857e-01,   5.91069239e-01,   5.33845945e-01,
#           4.29996263e-01,   2.77400812e-01,   1.20566599e-01,
#           4.85076362e-02,   3.15525862e-02,   7.18208301e-02,
#           7.39402113e-02,   7.39402113e-02,   8.66564989e-02,
#           1.29044124e-01,   2.01103087e-01,   2.28655043e-01,
#           2.09580612e-01,   1.56596080e-01,   1.41760412e-01,
#           1.62954224e-01,   2.18058137e-01,   2.85878337e-01,
#           2.96475244e-01,   2.87997719e-01,   2.58326381e-01,
#           2.49848856e-01,   2.62565143e-01,   2.73162050e-01,
#           2.71042668e-01,   2.66803906e-01,   2.43490712e-01,
#           2.13819374e-01]])

# %%
model = pickle.load(open("finalized_model.sav",'rb'))
y_pred = model.predict(X_test)
prediction = np.round(y_pred)[0]

res="Yes" if (prediction==1) else "No"
print("Result is",res)
# Out:
# Result is Yes
